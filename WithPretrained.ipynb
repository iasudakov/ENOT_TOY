# %% [markdown]
# # Toy Experiments

# %%
import os, sys
sys.path.append("..")

from src import distributions

import torch
from torch import nn
from torch.optim import Adam
import torch.nn.functional as F
from basic import ScoreNetwork

import numpy as np

from matplotlib import pyplot as plt

from tqdm import tqdm
from IPython.display import clear_output

from src.plotters import plot_results

from src.plotters import plot_trajectories

import os
SEED = 0xBADBEEF
torch.manual_seed(SEED); np.random.seed(SEED)

# %%
X_sampler = distributions.StandardNormalSampler(dim=2, device="cuda")
Y_sampler = distributions.SwissRollSampler(device="cuda")
# Y_sampler = distributions.Mix8GaussiansSampler(std=0.1, r=np.sqrt(2), device="cuda")

DIM = 2
H = 100

batch_size = 1000
lr = 1e-4
n_steps = 100
GAMMA = 0.0
G_ITERS = 5
D_ITERS = 1
f_ITERS = 2
MAX_STEPS = 50000


ZC = 1
Z_STD = 1.0

# %%
def trainNOT(X_sampler, Y_sampler, G, G_opt, D, D_opt, plot_n_samples=500):

    G_mse = []
    G_var = []
    sde_mse = []
    sde_var = []
    
    for step in tqdm(range(MAX_STEPS)):

        for G_iter in range(G_ITERS):

            x0 = X_sampler.sample(batch_size)
            Z = torch.randn(batch_size, ZC, device='cuda') * Z_STD
            xN = G(torch.cat([x0, Z], axis = -1))
            
            G_loss = F.mse_loss(x0, xN).mean() - D(xN).mean()
            
            G_opt.zero_grad(); G_loss.backward(); G_opt.step()
        
        
        # plotter 1
        if step % 1000 == 0:
            clear_output(wait=True)
            
            original_dataset = torch.cat(
                [X_sampler.sample(batch_size) for i in range(plot_n_samples//batch_size + 1)],
                dim=0,
            )[:plot_n_samples].cpu()
            target_dataset = torch.cat(
                [Y_sampler.sample(batch_size) for i in range(plot_n_samples//batch_size + 1)],
                dim=0,
            )[:plot_n_samples].cpu()
            
            X = X_sampler.sample(plot_n_samples)
            # G_dataset = G(X).detach().cpu()
            
            Z = torch.randn(plot_n_samples, ZC, device='cuda') * Z_STD
            G_dataset = G(torch.cat([X, Z], axis = -1)).detach().cpu()

            G_mse.append(F.mse_loss(X.detach().cpu(), G_dataset).item())
            print('G mse:', G_mse[-1])


            with torch.no_grad():
                X = X_sampler.sample(10000)

                T_XZ_np = []
                
                # Our method results G
                for i in range(100):
                    Z = torch.randn(10000, ZC, device='cuda') * Z_STD
                    T_XZ_np.append(G(torch.cat([X, Z], axis = -1)).cpu().numpy())
            
                T_XZ_np = np.array(T_XZ_np)
                G_var.append(T_XZ_np.var(axis=0).mean(axis=0).mean().item())
                print('G var:', G_var[-1])
            
            
            plot_results(original_dataset, G_dataset, target_dataset)
            plt.show()
    
        # plotter 2
        # if step % 100 == 0:
        #     clear_output(wait=True)
        #     print("Step", step)
        #     print("Plotting")
            
        #     fig, axes = plot_trajectories(X_sampler, G, ZC, Z_STD, sde, k=4)
        #     plt.show()
            
        for D_iter in range(D_ITERS):    
            x0 = X_sampler.sample(batch_size)
            x1 = Y_sampler.sample(batch_size)
            Z = torch.randn(batch_size, ZC, device='cuda') * Z_STD
            xN = G(torch.cat([x0, Z], axis = -1))
            D_loss = (- D(x1) + D(xN)).mean()
            D_opt.zero_grad(); D_loss.backward(); D_opt.step()

    return (G_mse, G_var, sde_mse, sde_var)

# %%
def trainBM(X_sampler, Y_sampler, f, f_opt, G, G_opt, sde, plot_n_samples=500):

    G_mse = []
    G_var = []
    sde_mse = []
    sde_var = []
    
    for step in tqdm(range(MAX_STEPS)):

        for G_iter in range(G_ITERS):

            for f_iter in range(f_ITERS):
                x0 = X_sampler.sample(batch_size)
                Z = torch.randn(batch_size, ZC, device='cuda') * Z_STD
                xN = G(torch.cat([x0, Z], axis = -1))
                
                t = (torch.rand(x0.shape[0])[:, None]*0.995).cuda()
                xt = x0 + (xN - x0) * t + torch.randn_like(x0)*torch.sqrt(t*(1-t)*GAMMA)
                
                f_loss = ((f(xt, t) - (xN - xt)/(1-t)) ** 2).mean()
                f_opt.zero_grad(); f_loss.backward(); f_opt.step()

        
        # plotter 1
        if step % 1000 == 0:
            clear_output(wait=True)
            
            original_dataset = torch.cat(
                [X_sampler.sample(batch_size) for i in range(plot_n_samples//batch_size + 1)],
                dim=0,
            )[:plot_n_samples].cpu()
            target_dataset = torch.cat(
                [Y_sampler.sample(batch_size) for i in range(plot_n_samples//batch_size + 1)],
                dim=0,
            )[:plot_n_samples].cpu()
            
            X = X_sampler.sample(plot_n_samples)
            # G_dataset = G(X).detach().cpu()
            
            Z = torch.randn(plot_n_samples, ZC, device='cuda') * Z_STD
            G_dataset = G(torch.cat([X, Z], axis = -1)).detach().cpu()
            f_dataset = sde(X).detach().cpu()

            G_mse.append(F.mse_loss(X.detach().cpu(), G_dataset).item())
            sde_mse.append(F.mse_loss(X.detach().cpu(), f_dataset).item())
            print('G mse:', G_mse[-1])
            print('sde mse:', sde_mse[-1])


            with torch.no_grad():
                X = X_sampler.sample(10000)

                T_XZ_np = []
                
                # Our method results G
                for i in range(100):
                    Z = torch.randn(10000, ZC, device='cuda') * Z_STD
                    T_XZ_np.append(G(torch.cat([X, Z], axis = -1)).cpu().numpy())
            
                T_XZ_np = np.array(T_XZ_np)
                G_var.append(T_XZ_np.var(axis=0).mean(axis=0).mean().item())
                print('G var:', G_var[-1])

                T_X_np = []
                for i in range(100):
                    T_X_np.append(sde(X).cpu().numpy())
            
                T_X_np = np.array(T_X_np)
                sde_var.append(T_X_np.var(axis=0).mean(axis=0).mean().item())
                print('sde var:', sde_var[-1])
            
            
            plot_results(f_dataset, G_dataset, target_dataset)
            plt.show()


    return (G_mse, G_var, sde_mse, sde_var)

# %%
def train(X_sampler, Y_sampler, f, f_opt, G, G_opt, D, D_opt, sde, plot_n_samples=500):

    G_mse = []
    G_var = []
    sde_mse = []
    sde_var = []
    
    for step in tqdm(range(MAX_STEPS)):

        for G_iter in range(G_ITERS):

            for f_iter in range(f_ITERS):
                x0 = X_sampler.sample(batch_size)
                Z = torch.randn(batch_size, ZC, device='cuda') * Z_STD
                xN = G(torch.cat([x0, Z], axis = -1))
                
                t = (torch.rand(x0.shape[0])[:, None]*0.995).cuda()
                xt = x0 + (xN - x0) * t + torch.randn_like(x0)*torch.sqrt(t*(1-t)*GAMMA)
                
                f_loss = ((f(xt, t) - (xN - xt)/(1-t)) ** 2).mean()
                f_opt.zero_grad(); f_loss.backward(); f_opt.step()

            x0 = X_sampler.sample(batch_size)
            Z = torch.randn(batch_size, ZC, device='cuda') * Z_STD
            xN = G(torch.cat([x0, Z], axis = -1))

            t = (torch.rand(x0.shape[0])[:, None]*0.995).cuda()
            xt = x0 + (xN - x0) * t + torch.randn_like(x0)*torch.sqrt(t*(1-t)*GAMMA)
            
            f_x_t = f(xt, t)
            E = (xN - xt)/(1-t)
            
            # G_loss = (f_x_t*E).mean() - (f_x_t*f_x_t).mean()/2 
            G_loss = (f_x_t*E).mean() - (f_x_t*f_x_t).mean()/2 - D(xN).mean()
            
            G_opt.zero_grad(); G_loss.backward(); G_opt.step()
        
        
        # plotter 1
        if step % 1000 == 0:
            clear_output(wait=True)
            
            original_dataset = torch.cat(
                [X_sampler.sample(batch_size) for i in range(plot_n_samples//batch_size + 1)],
                dim=0,
            )[:plot_n_samples].cpu()
            target_dataset = torch.cat(
                [Y_sampler.sample(batch_size) for i in range(plot_n_samples//batch_size + 1)],
                dim=0,
            )[:plot_n_samples].cpu()
            
            X = X_sampler.sample(plot_n_samples)
            # G_dataset = G(X).detach().cpu()
            
            Z = torch.randn(plot_n_samples, ZC, device='cuda') * Z_STD
            G_dataset = G(torch.cat([X, Z], axis = -1)).detach().cpu()
            f_dataset = sde(X).detach().cpu()

            G_mse.append(F.mse_loss(X.detach().cpu(), G_dataset).item())
            sde_mse.append(F.mse_loss(X.detach().cpu(), f_dataset).item())
            print('G mse:', G_mse[-1])
            print('sde mse:', sde_mse[-1])


            with torch.no_grad():
                X = X_sampler.sample(10000)

                T_XZ_np = []
                
                # Our method results G
                for i in range(100):
                    Z = torch.randn(10000, ZC, device='cuda') * Z_STD
                    T_XZ_np.append(G(torch.cat([X, Z], axis = -1)).cpu().numpy())
            
                T_XZ_np = np.array(T_XZ_np)
                G_var.append(T_XZ_np.var(axis=0).mean(axis=0).mean().item())
                print('G var:', G_var[-1])

                T_X_np = []
                for i in range(100):
                    T_X_np.append(sde(X).cpu().numpy())
            
                T_X_np = np.array(T_X_np)
                sde_var.append(T_X_np.var(axis=0).mean(axis=0).mean().item())
                print('sde var:', sde_var[-1])
            
            
            plot_results(f_dataset, G_dataset, target_dataset)
            plt.show()
    
        # plotter 2
        # if step % 100 == 0:
        #     clear_output(wait=True)
        #     print("Step", step)
        #     print("Plotting")
            
        #     fig, axes = plot_trajectories(X_sampler, G, ZC, Z_STD, sde, k=4)
        #     plt.show()
            
        for D_iter in range(D_ITERS):    
            x0 = X_sampler.sample(batch_size)
            x1 = Y_sampler.sample(batch_size)
            Z = torch.randn(batch_size, ZC, device='cuda') * Z_STD
            xN = G(torch.cat([x0, Z], axis = -1))
            D_loss = (- D(x1) + D(xN)).mean()
            D_opt.zero_grad(); D_loss.backward(); D_opt.step()

    return (G_mse, G_var, sde_mse, sde_var)

# %% [markdown]
# ## 4. Training

# %%
f = ScoreNetwork().cuda()

class f_X1(torch.nn.Module):
    def __init__(self):
        super().__init__()
        self.X1NN = ScoreNetwork().cuda()

    def forward(self, x, t):
        return (self.X1NN(x, t) - x)/(1-t)


G = nn.Sequential(
    nn.Linear(DIM+ZC, H),
    nn.ReLU(True), 
    nn.Linear(H, H),
    nn.ReLU(True),
    nn.Linear(H, H),
    nn.ReLU(True),
    nn.Linear(H, DIM)
).cuda()


D = nn.Sequential(
    nn.Linear(DIM, H),
    nn.ReLU(True),
    nn.Linear(H, H),
    nn.ReLU(True),
    nn.Linear(H, H),
    nn.ReLU(True),
    nn.Linear(H, 1)
).cuda()
    

class G_mu(torch.nn.Module):

    def __init__(self, x_dim=2):
        super().__init__()
        self.mu = torch.nn.Parameter(torch.randn(x_dim))
        self.s = torch.nn.Parameter(torch.tensor(torch.randn(1)[0]))

    def forward(self, x):
        return x[:, :2] + self.mu + x[:, 2:]*self.s
    
G1 = G_mu().cuda()
f1 = f_X1().cuda()


f_opt = Adam(f.parameters(), lr=lr)
G_opt = Adam(G.parameters(), lr=lr)
D_opt = Adam(D.parameters(), lr=lr)
G1_opt = Adam(G1.parameters(), lr=lr)
f1_opt = Adam(f1.parameters(), lr=lr)


class SDE(nn.Module):
    def __init__(self, shift_model, n_steps):
        super().__init__()
        self.shift_model = shift_model
        self.n_steps = n_steps
        self.delta_t = 1/n_steps
    
    def forward(self, x0, traj = False):
        x, t = x0, 0.0
        trajectory = [x]
        for step in range(self.n_steps):
            batch_size = x.shape[0]
            x = x + self.delta_t*self.shift_model(x, torch.tensor(t).repeat(batch_size)[:, None].cuda()) + torch.randn_like(x)*np.sqrt(GAMMA*self.delta_t)
            t += self.delta_t
            trajectory.append(x)
        if traj:
            return x, trajectory
        return x
# Out:
# /tmp/ipykernel_11480/2756377946.py:39: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.s = torch.nn.Parameter(torch.tensor(torch.randn(1)[0]))

# %%
# sde = SDE(shift_model=f1, n_steps=n_steps).cuda()
# stats = train(X_sampler, Y_sampler, f1, f1_opt, G, G_opt, D, D_opt, sde, plot_n_samples=1000)

# %%
# stats = trainNOT(X_sampler, Y_sampler, G, G_opt, D, D_opt, plot_n_samples=1000)

# %%
# torch.save(G, 'G.pt')
# torch.save(D, 'D.pt')

# %%
# sde = SDE(shift_model=f, n_steps=n_steps).cuda()
# stats = trainBM(X_sampler, Y_sampler, f, f_opt, G, G_opt, sde, plot_n_samples=1000)

# %%
# torch.save(f, 'f.pt')

# %%
f = torch.load('f.pt')
G = torch.load('G.pt')
D = torch.load('D.pt')
sde = SDE(shift_model=f, n_steps=n_steps).cuda()

# %%
batch_size = 1000
lr = 1e-4
n_steps = 100
GAMMA = 0.1
G_ITERS = 5
D_ITERS = 1
f_ITERS = 2
MAX_STEPS = 50000


ZC = 1
Z_STD = 1.0

# %%
stats = trainBM(X_sampler, Y_sampler, f, f_opt, G, G_opt, sde, plot_n_samples=1000)
# Out:
# G mse: 0.17522835731506348
# sde mse: 0.23001502454280853
# G var: 0.002812494756653905
# sde var: 0.08528004586696625
# 100%|██████████| 50000/50000 [13:33<00:00, 61.43it/s]

# %%
stats = train(X_sampler, Y_sampler, f, f_opt, G, G_opt, D, D_opt, sde, plot_n_samples=1000)
# Out:
# G mse: 0.1877121776342392
# sde mse: 0.24731798470020294
# G var: 0.0025985788088291883
# sde var: 0.08470825105905533
#  33%|███▎      | 16410/50000 [06:55<14:10, 39.50it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 stats = train(X_sampler, Y_sampler, f, f_opt, G, G_opt, D, D_opt, sde, plot_n_samples=1000)
#
# Cell In[5], line 106, in train(X_sampler, Y_sampler, f, f_opt, G, G_opt, D, D_opt, sde, plot_n_samples)
#     104         xN = G(torch.cat([x0, Z], axis = -1))
#     105         D_loss = (- D(x1) + D(xN)).mean()
# --> 106         D_opt.zero_grad(); D_loss.backward(); D_opt.step()
#     108 return (G_mse, G_var, sde_mse, sde_var)
#
# File ~/miniconda3/envs/not/lib/python3.10/site-packages/torch/optim/optimizer.py:268, in Optimizer.profile_hook_step.<locals>.wrapper(*args, **kwargs)
#     265 @functools.wraps(func)
#     266 def wrapper(*args, **kwargs):
#     267     self, *_ = args
# --> 268     profile_name = "Optimizer.step#{}.step".format(self.__class__.__name__)
#     269     with torch.autograd.profiler.record_function(profile_name):
#     270         # call optimizer step pre hooks
#     271         for pre_hook in chain(_global_optimizer_pre_hooks.values(), self._optimizer_step_pre_hooks.values()):
#
# KeyboardInterrupt:
